# %% [markdown]
# # Subset barcode runs
# This Python Jupyter notebook is creates a copy of the barcode runs file that contains just specific samples.
#
# First, import Python modules:

# %%
import os

import pandas as pd

import yaml

# %% [markdown]
# Read in the "master" barcode runs CSV file and the runs used to compute the escape scores for each sample:

# %%
with open('../config.yaml') as f:
    config = yaml.safe_load(f)

barcode_runs_file = os.path.join('../', config['barcode_runs'])
print(f"Reading barcode runs from {barcode_runs_file}")
barcode_runs = pd.read_csv(barcode_runs_file)

escape_score_samples_file = os.path.join('../', config['escape_score_samples'])
print(f"Reading escape score samples from {escape_score_samples_file}")
escape_score_samples = pd.read_csv(escape_score_samples_file)
# Out:
# Reading barcode runs from ../data/barcode_runs.csv
# Reading escape score samples from ../results/escape_scores/samples.csv

# %% [markdown]
# Now read in the samples to subset:

# %%
samples_to_subset_df = pd.read_csv('samples_to_subset.csv')
print('Here are the samples we will subset to:')
display(samples_to_subset_df)

samples_to_subset = samples_to_subset_df['sample'].tolist()
assert len(samples_to_subset) == len(set(samples_to_subset)), 'duplicate samples to subset'
# Out:
# Here are the samples we will subset to:
#                      sample
# 0                CR3022_400
# 1             COV2-2677_400
# 2             COV2-2082_400
# 3             COV2-2094_400
# 4             COV2-2165_400
# 5             COV2-2832_400
# 6             COV2-2479_400
# 7             COV2-2050_400
# 8             COV2-2096_400
# 9             COV2-2499_400
# 10              23_d21_1250
# 11              23_d45_1250
# 12              23_d120_500
# 13               1C_d26_200
# 14              1C_d113_200
# 15              24C_d32_200
# 16             24C_d104_200
# 17               6C_d33_500
# 18               6C_d76_500
# 19              22C_d28_200
# 20             22C_d104_200
# 21              25C_d48_200
# 22              25C_d115_80
# 23               25_d18_500
# 24               25_d94_200
# 25              12C_d61_160
# 26              12C_d152_80
# 27               23C_d26_80
# 28              23C_d102_80
# 29               13_d15_200
# 30             13_d121_1250
# 31               7C_d29_500
# 32              7C_d103_200
# 33                  CB6_400
# 34            REGN10933_400
# 35            REGN10987_400
# 36  REGN10933+REGN10987_400

# %% [markdown]
# Now get all the escape-score samples of interest:

# %%
if not set(samples_to_subset).issubset(escape_score_samples['name']):
    raise ValueError(f"Not all samples to subset are in the escape score samples.")
    
samples_subset = (
    escape_score_samples
    .query('name in @samples_to_subset')
    .reset_index(drop=True)
    )

print(f"Here are the samples for which we are subsetting barcode runs:")
display(samples_subset)
# Out:
# Here are the samples for which we are subsetting barcode runs:
#                        name library             antibody concentration  \
# 0               12C_d152_80    lib1             12C_d152            80
# 1               12C_d152_80    lib2             12C_d152            80
# 2               12C_d61_160    lib1              12C_d61           160
# 3               12C_d61_160    lib2              12C_d61           160
# 4              13_d121_1250    lib1              13_d121          1250
# ..                      ...     ...                  ...           ...
# 69            REGN10933_400    lib2            REGN10933           400
# 70  REGN10933+REGN10987_400    lib1  REGN10933+REGN10987           400
# 71  REGN10933+REGN10987_400    lib2  REGN10933+REGN10987           400
# 72            REGN10987_400    lib1            REGN10987           400
# 73            REGN10987_400    lib2            REGN10987           400
#
#    concentration_units    date                   pre_sample  \
# 0             dilution  200910  expt_34-41-none-0-reference
# 1             dilution  200910  expt_34-41-none-0-reference
# 2             dilution  200910  expt_34-41-none-0-reference
# 3             dilution  200910  expt_34-41-none-0-reference
# 4             dilution  200917  expt_46-52-none-0-reference
# ..                 ...     ...                          ...
# 69           ng_per_mL  200904  expt_24-33-none-0-reference
# 70           ng_per_mL  200904  expt_24-33-none-0-reference
# 71           ng_per_mL  200904  expt_24-33-none-0-reference
# 72           ng_per_mL  200904  expt_24-33-none-0-reference
# 73           ng_per_mL  200904  expt_24-33-none-0-reference
#
#                                post_sample  frac_escape  pre_cells_sorted  \
# 0               expt_40-12C_d152-80-escape        0.040          530574.0
# 1               expt_40-12C_d152-80-escape        0.052          528440.0
# 2               expt_37-12C_d61-160-escape        0.033          289524.0
# 3               expt_37-12C_d61-160-escape        0.031          373381.0
# 4              expt_52-13_d121-1250-escape        0.042          521978.0
# ..                                     ...          ...               ...
# 69            expt_24-REGN10933-400-escape        0.154          984237.0
# 70  expt_26-REGN10933+REGN10987-400-escape        0.101          635898.0
# 71  expt_26-REGN10933+REGN10987-400-escape        0.083          585188.0
# 72            expt_25-REGN10987-400-escape        0.148         1155004.0
# 73            expt_25-REGN10987-400-escape        0.150         1091502.0
#
#     post_cells_sorted
# 0         160000000.0
# 1         160000000.0
# 2         160000000.0
# 3         160000000.0
# 4                 NaN
# ..                ...
# 69        160000000.0
# 70        160000000.0
# 71        160000000.0
# 72        160000000.0
# 73        160000000.0
#
# [74 rows x 11 columns]

# %% [markdown]
# Now unfold the samples of interest into the actual relevant barcode runs (this requires getting both the pre- and post-selection run for each sample):

# %%
barcode_runs_subset = (
    samples_subset
    .melt(id_vars=['name', 'library'],
          value_vars=['pre_sample', 'post_sample'],
          value_name='sample',
          var_name='sample_type')
    [['library', 'sample']]
    .drop_duplicates()
    .reset_index(drop=True)
    .merge(barcode_runs,
           how='left',
           on=['library', 'sample'],
           validate='one_to_one',
           )
    )

assert barcode_runs_subset['R1'].notnull().all(), 'some barcode runs missing R1'

barcode_runs_subset_file = 'barcode_runs_subset.csv'
print(f"Here are the subsetted barcode runs. Writing to {barcode_runs_subset_file}")
barcode_runs_subset.to_csv(barcode_runs_subset_file, index=False)
display(barcode_runs_subset)
# Out:
# Here are the subsetted barcode runs. Writing to barcode_runs_subset.csv
#    library                                  sample    date  experiment  \
# 0     lib1             expt_34-41-none-0-reference  200910  expt_34-41
# 1     lib2             expt_34-41-none-0-reference  200910  expt_34-41
# 2     lib1             expt_46-52-none-0-reference  200917  expt_46-52
# 3     lib2             expt_46-52-none-0-reference  200917  expt_46-52
# 4     lib1             expt_24-33-none-0-reference  200904  expt_24-33
# ..     ...                                     ...     ...         ...
# 85    lib2            expt_24-REGN10933-400-escape  200904     expt_24
# 86    lib1  expt_26-REGN10933+REGN10987-400-escape  200904     expt_26
# 87    lib2  expt_26-REGN10933+REGN10987-400-escape  200904     expt_26
# 88    lib1            expt_25-REGN10987-400-escape  200904     expt_25
# 89    lib2            expt_25-REGN10987-400-escape  200904     expt_25
#
#                antibody concentration concentration_units           group  \
# 0                  none             0            dilution  clinical_serum
# 1                  none             0            dilution  clinical_serum
# 2                  none             0            dilution  clinical_serum
# 3                  none             0            dilution  clinical_serum
# 4                  none             0           ng_per_mL  clinical_serum
# ..                  ...           ...                 ...             ...
# 85            REGN10933           400           ng_per_mL  clinical_serum
# 86  REGN10933+REGN10987           400           ng_per_mL  clinical_serum
# 87  REGN10933+REGN10987           400           ng_per_mL  clinical_serum
# 88            REGN10987           400           ng_per_mL  clinical_serum
# 89            REGN10987           400           ng_per_mL  clinical_serum
#
#     selection  frac_escape  cells_sorted  \
# 0   reference          NaN   160000000.0
# 1   reference          NaN   160000000.0
# 2   reference          NaN           NaN
# 3   reference          NaN           NaN
# 4   reference          NaN   160000000.0
# ..        ...          ...           ...
# 85     escape        0.154      984237.0
# 86     escape        0.101      635898.0
# 87     escape        0.083      585188.0
# 88     escape        0.148     1155004.0
# 89     escape        0.150     1091502.0
#
#                                                    R1
# 0   /shared/ngs/illumina/agreaney/200914_D00300_10...
# 1   /shared/ngs/illumina/agreaney/200914_D00300_10...
# 2   /shared/ngs/illumina/agreaney/201012_D00300_10...
# 3   /shared/ngs/illumina/agreaney/201012_D00300_10...
# 4   /shared/ngs/illumina/agreaney/200914_D00300_10...
# ..                                                ...
# 85  /shared/ngs/illumina/agreaney/201012_D00300_10...
# 86  /shared/ngs/illumina/agreaney/201012_D00300_10...
# 87  /shared/ngs/illumina/agreaney/201012_D00300_10...
# 88  /shared/ngs/illumina/agreaney/201012_D00300_10...
# 89  /shared/ngs/illumina/agreaney/201012_D00300_10...
#
# [90 rows x 12 columns]
